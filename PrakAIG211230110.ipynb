# %% [markdown]
# <a href="https://colab.research.google.com/github/aderisky2602/ade/blob/main/PrakAIG211230110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#perintah untuk mengisi
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import sklearn.metrics as sm
dataset = pd.read_excel('dataPenjualan2024.xlsx')
dataset.head()
# Out:
#    biayaPromosi  nilaiPenjualan
# 0          1500           90500
# 1          1800           89500
# 2          1900          105000
# 3          2050          102000
# 4          2050           90500

# %%
dataset.plot(x='biayaPromosi' ,y='nilaiPenjualan' ,style='o')
plt.title('biayaPromosi Vs nilaiPenjualan')
plt.xlabel('biayaPromosi ()')
plt.ylabel('NilaiPenjualan')
plt.show()

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
y
# Out:
# array([ 90500,  89500, 105000, 102000,  90500, 104500, 109500, 150000,
#        152000, 173000, 153000, 174500, 150000, 198000, 187000, 194500,
#        200500, 170500, 204500, 224500])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test , y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()
