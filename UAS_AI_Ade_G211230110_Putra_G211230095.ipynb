# %% [markdown]
# <a href="https://colab.research.google.com/github/aderisky2602/ade/blob/main/UAS_AI_Ade_G211230110_Putra_G211230095.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#memasukan data testing ke datalatih
datalatih = pd.read_csv("data_testing.csv")
datalatih.head(11)
#Prestasi Siswa = 1 == Ya
#Prestasi Siswa = 2 == Tidak
#Prestasi Sekolah = 1 == Cukup
#Prestasi Sekolah = 2 == Baik
# Out:
#              Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0         Matematika          92              86                88
# 1         Matematika          90              86                85
# 2     Sastra Inggris          82              87                92
# 3         Matematika          93              82                85
# 4     Sastra Inggris          86              85                88
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                1                 1
# 1                1                 2
# 2                2                 1
# 3                1                 1
# 4                1                 1
# 5                2                 2
# 6                2                 1
# 7                1                 1
# 8                1                 1
# 9                2                 2
# 10               2                 1

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Jurusan           11 non-null     object
#  1   Matematika        11 non-null     int64
#  2   Bahasa Inggris    11 non-null     int64
#  3   Bahasa Indonesia  11 non-null     int64
#  4   Prestasi Siswa    11 non-null     int64
#  5   Prestasi Sekolah  11 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 656.0+ bytes

# %%
from sklearn.cluster import KMeans
#Memvisualkan persebaran data
plt.scatter(datalatih.Matematika, datalatih.Jurusan, s = 75, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["Jurusan"], axis=1)
x.head(11)
# Out:
#     Matematika  Bahasa Inggris  Bahasa Indonesia  Prestasi Siswa  \
# 0           92              86                88               1
# 1           90              86                85               1
# 2           82              87                92               2
# 3           93              82                85               1
# 4           86              85                88               1
# 5           91              83                84               2
# 6           88              80                90               2
# 7           84              82                88               1
# 8           79              89                85               1
# 9           83              88                81               2
# 10          82              85                84               2
#
#     Prestasi Sekolah
# 0                  1
# 1                  2
# 2                  1
# 3                  1
# 4                  1
# 5                  2
# 6                  1
# 7                  1
# 8                  1
# 9                  2
# 10                 1

# %%
y = datalatih["Jurusan"]
y.head(11)
# Out:
# 0           Matematika
# 1           Matematika
# 2       Sastra Inggris
# 3           Matematika
# 4       Sastra Inggris
# 5           Matematika
# 6     Sastra Indonesia
# 7     Sastra Indonesia
# 8       Sastra Inggris
# 9       Sastra Inggris
# 10      Sastra Inggris
# Name: Jurusan, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import GaussianNB

# %%
modelnb = GaussianNB()
# Memasukkan data training pada fungsi klasifikasi naive bayes
nbtrain = modelnb.fit(x, y)
datauji = pd.read_csv("data_testing.csv")
datauji.head(11)
# Out:
#              Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0         Matematika          92              86                88
# 1         Matematika          90              86                85
# 2     Sastra Inggris          82              87                92
# 3         Matematika          93              82                85
# 4     Sastra Inggris          86              85                88
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                1                 1
# 1                1                 2
# 2                2                 1
# 3                1                 1
# 4                1                 1
# 5                2                 2
# 6                2                 1
# 7                1                 1
# 8                1                 1
# 9                2                 2
# 10               2                 1

# %%
x_test = datauji.drop(["Jurusan"], axis=1)
x_test.head(11)
# Out:
#     Matematika  Bahasa Inggris  Bahasa Indonesia  Prestasi Siswa  \
# 0           92              86                88               1
# 1           90              86                85               1
# 2           82              87                92               2
# 3           93              82                85               1
# 4           86              85                88               1
# 5           91              83                84               2
# 6           88              80                90               2
# 7           84              82                88               1
# 8           79              89                85               1
# 9           83              88                81               2
# 10          82              85                84               2
#
#     Prestasi Sekolah
# 0                  1
# 1                  2
# 2                  1
# 3                  1
# 4                  1
# 5                  2
# 6                  1
# 7                  1
# 8                  1
# 9                  2
# 10                 1

# %%
y_uji = datauji["Jurusan"]
y_uji.head(11)
# Out:
# 0           Matematika
# 1           Matematika
# 2       Sastra Inggris
# 3           Matematika
# 4       Sastra Inggris
# 5           Matematika
# 6     Sastra Indonesia
# 7     Sastra Indonesia
# 8       Sastra Inggris
# 9       Sastra Inggris
# 10      Sastra Inggris
# Name: Jurusan, dtype: object

# %%
Y_predict = nbtrain.predict(x_test)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# Prediksi Naive Bayes :  ['Matematika' 'Matematika' 'Sastra Inggris' 'Matematika'
#  'Sastra Indonesia' 'Matematika' 'Sastra Indonesia' 'Sastra Indonesia'
#  'Sastra Inggris' 'Sastra Inggris' 'Sastra Inggris']

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_uji, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# Akurasi Naive Bayes :  0.9090909090909091

# %%
from sklearn.metrics import classification_report
print(classification_report(y_uji, Y_predict))
# Out:
#                   precision    recall  f1-score   support
#
#       Matematika       1.00      1.00      1.00         4
# Sastra Indonesia       0.67      1.00      0.80         2
#   Sastra Inggris       1.00      0.80      0.89         5
#
#         accuracy                           0.91        11
#        macro avg       0.89      0.93      0.90        11
#     weighted avg       0.94      0.91      0.91        11
