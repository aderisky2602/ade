# %% [markdown]
# <a href="https://colab.research.google.com/github/aderisky2602/ade/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Mengimpor data dari file Excel dengan mengatur agar melewati baris tambahan
file_path = '61.-jumlah-penderita-diare-yang-datang-dan-dilayani-disarana-kesehatan.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet1', skiprows=9)  # Menyesuaikan jumlah baris yang dilewati

# Menetapkan nama kolom secara manual jika tidak terbaca dengan benar
data.columns = ['No', 'Kecamatan', 'Puskesmas', 'Jumlah Penduduk', 'Jumlah Target Penemuan',
                'Diare Balita', 'Diare Semua Umur', 'Jumlah Persen Balita', 'Jumlah Persen Semua Umur',
                'Mendapat Oralit Semua Umur', 'Persen Oralit Semua Umur', 'Mendapat Oralit Balita',
                'Persen Oralit Balita', 'Mendapat Zinc Semua Umur', 'Mendapat Zinc Balita',
                'Persen Zinc Balita']

# Menghapus baris kosong yang mungkin terbaca
data = data.dropna(how='all')

# Menampilkan 5 baris pertama untuk memastikan data terimpor dengan benar
data.head()
# Out:
#   No   Kecamatan               Puskesmas  Jumlah Penduduk  \
# 0  1           2                       3              4.0
# 1  1    MRANGGEN    Puskesmas Mranggen I          59168.0
# 2  2    MRANGGEN   Puskesmas Mranggen II          48125.0
# 3  3    MRANGGEN  Puskesmas Mranggen III          70915.0
# 4  4  KARANGAWEN  Puskesmas Karangawen I          41907.0
#
#    Jumlah Target Penemuan  Diare Balita  Diare Semua Umur  \
# 0                   5.000        6.0000               7.0
# 1                1597.536      658.2144             439.0
# 2                1299.375      586.7280             197.0
# 3                1914.705      692.4402            1104.0
# 4                1131.489      426.5580            1317.0
#
#    Jumlah Persen Balita  Jumlah Persen Semua Umur  Mendapat Oralit Semua Umur  \
# 0              8.000000                       9.0                   10.000000
# 1             27.479819                     147.0                   22.333149
# ...
